# %%
import pandas as pd
import seaborn as sns

# %%
df = sns.load_dataset("tips")

# %%
df.head
# Out:
# <bound method NDFrame.head of      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]>

# %%
# Group by 'day' and describe numeric columns
grouped_stats = df.groupby('day')['total_bill'].agg(['mean', 'median', 'min', 'max', 'std'])
print(grouped_stats)
# Out:
#            mean  median   min    max       std
# day
# Thur  17.682742   16.20  7.51  43.11  7.886170
# Fri   17.151579   15.38  5.75  40.17  8.302660
# Sat   20.441379   18.24  3.07  50.81  9.480419
# Sun   21.410000   19.63  7.25  48.17  8.832122
# /tmp/ipykernel_15730/635347044.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_stats = df.groupby('day')['total_bill'].agg(['mean', 'median', 'min', 'max', 'std'])

# %%
stats_by_species = df.groupby('day').describe()
print(stats_by_species)
# Out:
#      total_bill                                                             \
#           count       mean       std   min      25%    50%      75%    max
# day
# Thur       62.0  17.682742  7.886170  7.51  12.4425  16.20  20.1550  43.11
# Fri        19.0  17.151579  8.302660  5.75  12.0950  15.38  21.7500  40.17
# Sat        87.0  20.441379  9.480419  3.07  13.9050  18.24  24.7400  50.81
# Sun        76.0  21.410000  8.832122  7.25  14.9875  19.63  25.5975  48.17
#
#        tip            ...                 size                                \
#      count      mean  ...     75%    max count      mean       std  min  25%
# day                   ...
# Thur  62.0  2.771452  ...  3.3625   6.70  62.0  2.451613  1.066285  1.0  2.0
# Fri   19.0  2.734737  ...  3.3650   4.73  19.0  2.105263  0.567131  1.0  2.0
# Sat   87.0  2.993103  ...  3.3700  10.00  87.0  2.517241  0.819275  1.0  2.0
# Sun   76.0  3.255132  ...  4.0000   6.50  76.0  2.842105  1.007341  2.0  2.0
#
#
# ...

# %%
# For each species, get detailed stats
for day in df['day'].unique():
    print(f"\nStatistics for {day.capitalize()}:")
    print(df[df['day'] == day].describe())
# Out:
# Statistics for Sun:
#        total_bill        tip       size
# count   76.000000  76.000000  76.000000
# mean    21.410000   3.255132   2.842105
# std      8.832122   1.234880   1.007341
# min      7.250000   1.010000   2.000000
# 25%     14.987500   2.037500   2.000000
# 50%     19.630000   3.150000   2.000000
# 75%     25.597500   4.000000   4.000000
# max     48.170000   6.500000   6.000000
#
# Statistics for Sat:
#        total_bill        tip       size
# count   87.000000  87.000000  87.000000
# mean    20.441379   2.993103   2.517241
# std      9.480419   1.631014   0.819275
# min      3.070000   1.000000   1.000000
# 25%     13.905000   2.000000   2.000000
# 50%     18.240000   2.750000   2.000000
# 75%     24.740000   3.370000   3.000000
# max     50.810000  10.000000   5.000000
#
# Statistics for Thur:
#        total_bill        tip       size
# count   62.000000  62.000000  62.000000
# mean    17.682742   2.771452   2.451613
# std      7.886170   1.240223   1.066285
# ...

# %%
df['total_bill'].mean
# Out:
# <bound method Series.mean of 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total_bill, Length: 244, dtype: float64>

# %%
df['tip'].mean()
# Out:
# 2.99827868852459

# %%
df['tip'].median()
# Out:
# 2.9

# %%
df['tip'].mode()
# Out:
# 0    2.0
# Name: tip, dtype: float64

# %%
df['tip'].std()
# Out:
# 1.3836381890011826

# %%
# 1. Import required libraries
import pandas as pd

# 2. Load iris dataset
df = pd.read_csv('Iris.csv')

# 3. Display basic statistical details for each species
species_list = ['Iris-setosa', 'Iris-versicolor', 'Iris-virginica']

for species in species_list:
    print(f"\nStatistics for {species}:")
    species_df = df[df['Species'] == species]
    print(species_df.describe())
# Out:
# Statistics for Iris-setosa:
#              Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  50.00000       50.00000     50.000000      50.000000      50.00000
# mean   25.50000        5.00600      3.418000       1.464000       0.24400
# std    14.57738        0.35249      0.381024       0.173511       0.10721
# min     1.00000        4.30000      2.300000       1.000000       0.10000
# 25%    13.25000        4.80000      3.125000       1.400000       0.20000
# 50%    25.50000        5.00000      3.400000       1.500000       0.20000
# 75%    37.75000        5.20000      3.675000       1.575000       0.30000
# max    50.00000        5.80000      4.400000       1.900000       0.60000
#
# Statistics for Iris-versicolor:
#               Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count   50.00000      50.000000     50.000000      50.000000     50.000000
# mean    75.50000       5.936000      2.770000       4.260000      1.326000
# ...

# %%
import pandas as pd
import seaborn as sns

df = sns.load_dataset("tips")
df.head

# Group by 'day' and describe numeric columns
grouped_stats = df.groupby('day')['total_bill'].agg(['mean', 'median', 'min', 'max', 'std'])
print(grouped_stats)

stats_by_species = df.groupby('day').describe()
print(stats_by_species)
